# %%
import pandas as pd

tabla = pd.read_csv('/content/students.csv')
tabla
# Out:
#         Id      User  Unnamed: 2      Pass Paternal     Maternal  \
# 0        1  12136038           1  70048933     ABAD      HUACHIN
# 1        2  24137004           1  76652472    ACUÑA  SAL Y ROSAS
# 2        3  21132022           1  79787815   ACURIO       ROBLES
# 3        4  21236022           1  76256614   ACOSTA     GONZALES
# 4        5  19137031           1  71470013   ACOSTA        YNUMA
# ...    ...       ...         ...       ...      ...          ...
# 2403  2404  18136002           1  41930879     PEÑA        GOMEZ
# 2404  2405  17136009           1  62483866     PEÑA       GUDIEL
# 2405  2406  22237004           1  61657879  PEDRAZA     PALOMINO
# 2406  2407  20237007           1  76810538      PAZ       HUAMAN
# 2407  2408  22132006           1  73248553      PAZ       FLORES
#
#                     Name                         Email     Faculty  Unnamed: 9
# 0          CARLOS DARWIN                             -  ECOTURISMO         NaN
# ...

# %%
# Ver cabeceras de columnas
tabla.columns
# Out:
# Index(['Id', 'User', 'Unnamed: 2', 'Pass', 'Paternal', 'Maternal', 'Name',
#        'Email', 'Faculty', 'Unnamed: 9'],
#       dtype='object')

# %%
# ver estructura del dataframe
tabla.shape
# Out:
# (2408, 10)

# %%
# Visualizar solo las 5 filas
tabla.head()
# Out:
#    Id      User  Unnamed: 2      Pass Paternal     Maternal  \
# 0   1  12136038           1  70048933     ABAD      HUACHIN
# 1   2  24137004           1  76652472    ACUÑA  SAL Y ROSAS
# 2   3  21132022           1  79787815   ACURIO       ROBLES
# 3   4  21236022           1  76256614   ACOSTA     GONZALES
# 4   5  19137031           1  71470013   ACOSTA        YNUMA
#
#                  Name                         Email     Faculty  Unnamed: 9
# 0       CARLOS DARWIN                             -  ECOTURISMO         NaN
# 1  ALEXANDER JONATHAN        24137004@unamad.edu.pe  ECOTURISMO         NaN
# 2                JOEL  jacurior21-1ec@unamad.edu.pe  ECOTURISMO         NaN
# 3    NAYDELINE HAJALE         8040403@unamad.edu.pe  ECOTURISMO         NaN
# 4       DIEGO LEANDRO  dacostay21-2cf@unamad.edu.pe  ECOTURISMO         NaN

# %%
# Visualizar las ultimas 5 filas
tabla.tail()
# Out:
#         Id      User  Unnamed: 2      Pass Paternal  Maternal  \
# 2403  2404  18136002           1  41930879     PEÑA     GOMEZ
# 2404  2405  17136009           1  62483866     PEÑA    GUDIEL
# 2405  2406  22237004           1  61657879  PEDRAZA  PALOMINO
# 2406  2407  20237007           1  76810538      PAZ    HUAMAN
# 2407  2408  22132006           1  73248553      PAZ    FLORES
#
#                  Name                   Email     Faculty  Unnamed: 9
# 2403   PAOLA GRACIELA   paolapg@unamad.edu.pe  ECOTURISMO         NaN
# 2404  ALBERTO BRANDON  abgudiel@unamad.edu.pe  ECOTURISMO         NaN
# 2405           MIGUEL  22237004@unamad.edu.pe  ECOTURISMO         NaN
# 2406    CARLOS MANUEL     cpazh@unamad.edu.pe  ECOTURISMO         NaN
# 2407    PEGGIE SELENA    ppaz22@unamad.edu.pe  ECOTURISMO         NaN

# %%
# Ver los tipos de datos
tabla.dtypes
# Out:
# Id              int64
# User            int64
# Unnamed: 2      int64
# Pass            int64
# Paternal       object
# Maternal       object
# Name           object
# Email          object
# Faculty        object
# Unnamed: 9    float64
# dtype: object

# %%
# Que datos estan vacios
tabla.isnull()
# Out:
#          Id   User  Unnamed: 2   Pass  Paternal  Maternal   Name  Email  \
# 0     False  False       False  False     False     False  False  False
# 1     False  False       False  False     False     False  False  False
# 2     False  False       False  False     False     False  False  False
# 3     False  False       False  False     False     False  False  False
# 4     False  False       False  False     False     False  False  False
# ...     ...    ...         ...    ...       ...       ...    ...    ...
# 2403  False  False       False  False     False     False  False  False
# 2404  False  False       False  False     False     False  False  False
# 2405  False  False       False  False     False     False  False  False
# 2406  False  False       False  False     False     False  False  False
# 2407  False  False       False  False     False     False  False  False
#
#       Faculty  Unnamed: 9
# 0       False        True
# 1       False        True
# ...

# %%
# Cuantos datos son nulos
tabla.isnull().sum()
# Out:
# Id               0
# User             0
# Unnamed: 2       0
# Pass             0
# Paternal         0
# Maternal         0
# Name             0
# Email           99
# Faculty         51
# Unnamed: 9    2408
# dtype: int64

# %%
# Informacion de cada columna, cuantas datos no nulos tengo ?
tabla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2408 entries, 0 to 2407
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          2408 non-null   int64
#  1   User        2408 non-null   int64
#  2   Unnamed: 2  2408 non-null   int64
#  3   Pass        2408 non-null   int64
#  4   Paternal    2408 non-null   object
#  5   Maternal    2408 non-null   object
#  6   Name        2408 non-null   object
#  7   Email       2309 non-null   object
#  8   Faculty     2357 non-null   object
#  9   Unnamed: 9  0 non-null      float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 188.2+ KB

# %% [markdown]
# En pandas se pueden realizar los siguientes tipos de calculos
#
# * promedio
# * suma
# * valor minimo
# * valor maximo
# * mediana
